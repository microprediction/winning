# %% [markdown]
# <a href="https://colab.research.google.com/github/microprediction/winning/blob/main/show_pricing_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade winning

# %%
from winning.lattice_pricing import skew_normal_simulation
dividends = [2.0,3.0,12.0,12.0,24.0,24.0]
pricing = skew_normal_simulation(dividends=dividends,longshot_expon=1.15,skew_parameter=1.0,nSamples=1000)

# %%
pricing['win']
# Out:
# [2.2271714922048997,
#  3.236245954692557,
#  11.11111111111111,
#  13.88888888888889,
#  24.390243902439025,
#  25.641025641025642]

# %%
pricing['show']
# Out:
# [1.183431952662722,
#  1.335113484646195,
#  2.3696682464454977,
#  2.2935779816513757,
#  3.846153846153846,
#  3.472222222222222]
